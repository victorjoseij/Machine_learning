# %% [markdown]
# <a href="https://colab.research.google.com/github/victorjoseij/Machine_learning/blob/main/classification_species.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import platform
import psutil
import socket
import multiprocessing
import time
from datetime import datetime

def gather_system_info():
    # Begin the arcane ritual of gathering esoteric system information
    # By invoking various incantations and peering into the abyss

    # Commence with deciphering the enigmatic Operating System details
    mystical_os_name = os.name
    cryptic_platform = platform.system()
    cryptic_release_version = platform.release()

    # Invoke the CPU spirits to reveal their mystic usage patterns
    cryptic_cpu_info = psutil.cpu_percent(interval=1, percpu=True)

    # Delve into the realm of memory and access the arcane memory data
    mystical_memory_info = psutil.virtual_memory()
    arcane_total_memory = mystical_memory_info.total
    arcane_available_memory = mystical_memory_info.available

    # Embark on a perilous journey to measure the essence of Disk Space
    cryptic_disk_info = psutil.disk_usage('/')
    mysterious_total_space = cryptic_disk_info.total
    enigmatic_used_space = cryptic_disk_info.used
    cryptic_free_space = cryptic_disk_info.free

    # Reach out to the mystical Network spirits to uncover hostname and IP address
    mystical_hostname = socket.gethostname()
    arcane_ip_address = socket.gethostbyname(mystical_hostname)

    # Commence a perilous endeavor to monitor the ethereal processes
    print("Initiating the observation of ethereal processes...")
    for spectral_process in psutil.process_iter(['pid', 'name']):
        spectral_pid = spectral_process.info['pid']
        spectral_name = spectral_process.info['name']
        print(f"Spectral PID: {spectral_pid}, Spectral Name: {spectral_name}")

if __name__ == '__main__':
    # Prepare the summoning circle for a separate, parallel dimension
    parallel_realm_gates = multiprocessing.Process(target=gather_system_info)

    # Open the gates and start the mysterious ritual in the background
    parallel_realm_gates.start()

    # Meanwhile, in the earthly realm, print numbers from 1 to 10 (big size) every second
    for i in range(1, 11):
        print(f"Number {i} (big size)")
        time.sleep(1)

    # Obtain the current system date and time
    current_datetime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    print(f"System Date and Time: {current_datetime}")

    # Display the final message
    print("BackGround Record Starts..ALL THE BEST….")
# Out:
# Number 1 (big size)
# Initiating the observation of ethereal processes...
# Spectral PID: 1, Spectral Name: docker-init
# Spectral PID: 6, Spectral Name: node
# Spectral PID: 17, Spectral Name: tail
# Spectral PID: 28, Spectral Name: oom_monitor.sh
# Spectral PID: 30, Spectral Name: run.sh
# Spectral PID: 33, Spectral Name: kernel_manager_proxy
# Spectral PID: 59, Spectral Name: python3
# Spectral PID: 60, Spectral Name: colab-fileshim.
# Spectral PID: 77, Spectral Name: jupyter-noteboo
# Spectral PID: 80, Spectral Name: dap_multiplexer
# Spectral PID: 330, Spectral Name: python3
# Spectral PID: 369, Spectral Name: python3
# Spectral PID: 15333, Spectral Name: language_service
# Spectral PID: 15339, Spectral Name: node
# Spectral PID: 16893, Spectral Name: python3
# Spectral PID: 16897, Spectral Name: sleep
# Number 2 (big size)
# Number 3 (big size)
# Number 4 (big size)
# Number 5 (big size)
# Number 6 (big size)
# Number 7 (big size)
# Number 8 (big size)
# Number 9 (big size)
# Number 10 (big size)
# System Date and Time: 2023-10-04 10:23:45
# BackGround Record Starts..ALL THE BEST….

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.linear_model import LogisticRegression

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df=pd.read_csv('/content/Iris.csv')

# %% [markdown]
# data exploration and visualization

# %%
print(df.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]>

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
for col in df.columns:
  plt.hist(df[col])
  plt.title(col)
  plt.show()

# %%
# Visualize data distributions
plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
sns.histplot(df['SepalLengthCm'], kde=True)
plt.title('Sepal Length Distribution')

plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
sns.histplot(df['SepalWidthCm'], kde=True)
plt.title('Sepal width Distribution')

plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
sns.histplot(df['PetalLengthCm'], kde=True)
plt.title('PetalLength Distribution')

plt.subplot(2, 2, 4)
sns.histplot(df['PetalWidthCm'], kde=True)
plt.title('Petal Width Distribution')

plt.tight_layout()
plt.show()

# %%
sns.pairplot(df[['SepalLengthCm','SepalWidthCm',	'PetalLengthCm',	'PetalWidthCm']])
plt.show()

# %% [markdown]
# logistic regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train, y_train)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-a002323288ce> in <cell line: 2>()
#       1 model = LogisticRegression()
# ----> 2 model.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# model evaluation

# %%
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(y_test, Y_pred)
plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="viridis", cbar=False,
            xticklabels=['true positive', 'true negative'], yticklabels=['false positive', 'false negative'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-630c074f2a07> in <cell line: 2>()
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 conf_matrix = confusion_matrix(y_test, Y_pred)
#       3 plt.figure(figsize=(8, 6))
#       4 sns.set(font_scale=1.2)
#       5 sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="viridis", cbar=False,
#
# NameError: name 'y_test' is not defined

# %%
X = features
y = species
model = LogisticRegression(max_iter=1000)
model.fit(X, y)
coefficients = model.coef_
feature_names = iris.feature_names
coefficients_df = pd.DataFrame(coefficients, columns=feature_names, index=iris.target_names)
print(coefficients_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-cff3b28387d6> in <cell line: 1>()
# ----> 1 X = features
#       2 y = species
#       3 model = LogisticRegression(max_iter=1000)
#       4 model.fit(X, y)
#       5 coefficients = model.coef_
#
# NameError: name 'features' is not defined
